# %%
import requests

# %%
url ="https://www.pse.com/ko/pages/electric-cars/electric-vehicles-faq"

head = {'user-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Safari/537.36 Edg/136.0.0.0'}
r = requests.get(url, headers=head)

# %%
from bs4 import BeautifulSoup

# %%
bs = BeautifulSoup(r.text)

# %%
print(bs.find("p", class_ = "collapsed").text.strip())
# Out:
# BEV와 PHEV의 차이점은 무엇입니까?

# %%
print(bs.find("div", class_ = "panel-body collapse-content").text.strip())
# Out:
# 전기 자동차에는 두 가지 유형이 있습니다. 배터리에 의존하여 전기 모터에 동력을 공급하는 전기 에너지를 저장하는 배터리 전용 EV와 전기 모터와 백업 가솔린 엔진을 모두 사용하여 주행 거리를 늘리는 플러그인 하이브리드 EV가 있습니다.2020년에는 워싱턴 주에 등록된 신차 중 90% 가 BEV였는데, 전기차에 대해 이야기할 때는 주로 전기차에 초점을 맞추는 경향이 있습니다.PHEV는 기존 자동차보다 연료 효율이 높지만 BEV와 동일한 재정적, 환경적 이점을 제공하지는 않습니다.

# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.pse.com/ko/pages/electric-cars/electric-vehicles-faq"
headers = {
    "User-Agent": "Mozilla/5.0"
}

res = requests.get(url, headers=headers)
soup = BeautifulSoup(res.text, "html.parser")

# 질문과 답변 추출
questions = soup.find_all("p", class_="collapsed")
answers = soup.find_all("div", class_="panel-body collapse-content")

# 리스트로 정리
faq_list = []
for q, a in zip(questions, answers):
    question = q.text.strip()
    answer = a.text.strip()
    faq_list.append((question, answer))

# %%
faq_list
# Out:
# [('BEV와 PHEV의 차이점은 무엇입니까?',
#   '전기 자동차에는 두 가지 유형이 있습니다. 배터리에 의존하여 전기 모터에 동력을 공급하는 전기 에너지를 저장하는 배터리 전용 EV와 전기 모터와 백업 가솔린 엔진을 모두 사용하여 주행 거리를 늘리는 플러그인 하이브리드 EV가 있습니다.2020년에는 워싱턴 주에 등록된 신차 중 90% 가 BEV였는데, 전기차에 대해 이야기할 때는 주로 전기차에 초점을 맞추는 경향이 있습니다.PHEV는 기존 자동차보다 연료 효율이 높지만 BEV와 동일한 재정적, 환경적 이점을 제공하지는 않습니다.'),
#  ('워싱턴 주에서는 몇 대의 EV 모델을 사용할 수 있습니까?',
#   '워싱턴에는 70개 이상의 완전 전기 모델이 있습니다.앞으로 몇 년 안에 많은 추가 모델이 시장에 출시될 것으로 예상됩니다.전기 자동차 가이드를 사용하여 최신 모델을 비교하고 예산과 운전 요구 사항에 맞는 모델을 찾으십시오.'),
#  ('전기 트럭을 이용할 수 있나요?사륜구동이 가능한 EV는 어떨까요?',
#   '이미 시장에 많은 전기 트럭이 출시되어 있으며 더 많은 모델이 출시될 예정입니다.전기 트럭은 가스 동력 트럭의 출력 및 견인 용량을 초과하지는 않더라도 동급 성능을 낼 수 있습니다.또한 시장에는 전륜 구동을 제공하는 전기 자동차 모델도 있습니다.당사의 전기 자동차 가이드는 최신 모델을 비교하고 필요에 맞는 모델을 찾는 데 도움이 될 수 있습니다.'),
#  ('중고 EV 시장이 있나요?',
#   '중고 전기 자동차 시장이 성장하고 있습니다.대부분의 중고 EV는 20,000달러 미만으로 구입할 수 있으며 여전히 원래 보증 기간이 남아 있습니다.게다가 EV 배터리는 처음에 예상했던 것보다 더 오래 수명을 유지하는 경향이 있습니다.심지어 워싱턴 주에서는 3만 달러 미만의 중고 전기차에 대해서만 판매세 면제를 제공하므로 1,000달러 이상의 판매세를 절약할 수 있습니다.'),
#  ('일반 자동차와 비교하여 EV를 소유하는 데 드는 비용은 얼마입니까?',
#   '연료와 유지보수 비용을 절감할 수 있기 때문에 전기 자동차를 소유하는 것이 실제로 휘발유 자동차보다 저렴할 수 있습니다.2018년 미시건 대학교의 연구에 따르면 전기차는 연간 운행 비용이 가스 구동 자동차에 비해 절반 미만인 것으로 나타났습니다.그리고 2020년 컨슈머 리포트 (Consumer Reports) 보고서에 따르면 전기차의 평균 높은 구매 가격을 고려하더라도 EV의 장기 소유 비용은 6,000달러에서 1만 달러 더 낮을 수 있습니다.당사의 전기 자동차 가이드를 사용하여 EV와 가스 구동 자동차 간의 장기 절감 효과를 비교할 수 있습니다.'),
#  ('일반 자동차와 비교하여 EV 구매 가격은 어떻습니까?',
#   '전기 자동차의 구매 가격은 동급 가스 구동 자동차보다 여전히 높습니다.그러나 기술의 발전과 전기 옵션을 제공하는 자동차 제조업체의 증가로 인해 EV 가격이 하락하고 있습니다.현재 40,000달러 (미국의 신차 평균 가격) 미만으로 12개의 EV 모델을 구입할 수 있습니다.그리고 전기차 중고 시장도 성장하고 있습니다.'),
#  ('전기 요금이 인상되나요?',
#   '대부분의 EV 소유주처럼 집에서 전기 자동차를 충전하면 월별 전기 요금이 인상되는 것을 볼 수 있습니다.하지만 전기 요금 인상액은 휘발유로 절약하는 비용보다 적을 것이 거의 확실합니다.얼마나 운전하느냐에 따라 휘발유에서 전기로 전환할 때 한 달에 100달러 이상의 연료를 쉽게 절약할 수 있습니다.'),
#  ('일반 자동차에 비해 EV에 연료를 공급하는 데 드는 비용은 얼마입니까?',
#   '현지 가스 및 전기 요금을 고려하면 전기 자동차에 연료를 공급하는 것이 가스 구동 자동차보다 약 5배 저렴할 수 있습니다.당사의 전기 자동차 가이드를 사용하여 전기차에 연료를 공급하는 데 드는 월별 비용과 수년간의 소유 비용을 비교해 보세요.'),
#  ('일반 자동차에 비해 EV를 유지하는 데 드는 비용은 얼마입니까?',
#   '전기 자동차는 가스 구동 자동차보다 움직이는 부품이 적기 때문에 유지 보수가 덜 필요합니다.오일 교환, 변속기 오일 또는 점화 플러그가 필요 없기 때문에 EV 소유자는 5년 동안 유지 보수 비용을 1,000달러 이상 절약할 수 있습니다.전기 자동차 가이드를 사용하여 EV와 가스 구동 자동차 간의 유지 보수 비용을 비교해 보세요.'),
#  ('EV 구매에 대한 주 및 연방 인센티브가 있습니까?',
#   '네!워싱턴 주의 판매세 면제에 따라 가격이 45,000달러 미만인 새 전기 자동차를 구입하면 최대 1,300달러를 절약하거나 3만 달러 미만의 중고 전기차를 1,000달러 이상 절약할 수 있습니다.한편, 연방 정부는 소득세 고지서 감면 또는 세금 환급 증액의 형태로 새 전기차에 대해 최대 7,500달러를 환급해 주고 있습니다.(연방 세금 환급은 현재 Chevy 또는 Tesla의 EV 모델에는 적용되지 않습니다.)전기차 가이드를 통해 자세히 알아보세요.'),
#  ('가정용 충전기 구매에 대한 주 및 연방 정부의 인센티브가 있습니까?',
#   '네!연방 대체 연료 인프라 세금 공제는 2021년 12월 31일 이전에 가정용 충전 장비를 구매한 고객에게 최대 1,000달러를 환급해 줍니다.한편, 워싱턴 주 전기차 인프라 세금 면제에 따라 가정용 충전기 구매 및 설치에 필요한 인건비 및 서비스에는 주 판매세 및 사용세가 적용되지 않습니다.전기 자동차 안내서를 통해 자세히 알아보십시오.'),
#  ('PSE는 사용량이 적은 시간대에 충전 시 할인을 제공하나요?',
#   'PSE는 현재 특정 시간 동안 전기 자동차 충전에 대한 할인을 제공하지 않지만, 충전과 관련된 다양한 방법과 인센티브를 계속 모색하고 있습니다.하루 중 특정 시간대에 EV를 충전하는 것이 여전히 중요한 이유를 알아보려면 여기를 클릭하십시오.'),
#  ('PSE는 가정용 충전기 및 설치에 대한 인센티브를 제공합니까?',
#   'PSE는 현재 적격 레벨 2 EV 가정용 충전기에 대해 리베이트를 제공합니다.이러한 리베이트는 PSE 마켓플레이스나 참여 PSE 추천 에너지 전문가를 통해 충전기를 구매한 경우 즉시 적용됩니다.적격 충전기에 대해서는 구매 후 환급도 받을 수 있습니다.적격 소득이 있는 고객은 EV 충전기 및 설치 비용에 대해 더 많은 Empower Mobility 인센티브를 받을 수 있습니다.자세한 내용은 pse.com/chargers를 참조하십시오.'),
#  ('PSE의 교통 전기화 계획이란 무엇입니까?',
#   '교통 전기화 계획은 전기 자동차 제품을 위한 5개년 전략 프레임워크로, PSE가 워싱턴 주의 전기 교통을 발전시켜 청정 에너지 미래로의 전환을 주도할 수 있도록 합니다.'),
#  ('PSE 고객은 운송 전기화를 통해 어떤 이점을 얻을 수 있습니까?',
#   '교통 전기화는 탄소 배출을 줄이고 대기 질 및 지역 사회 건강을 개선하는 동시에 PSE 서비스 지역 전체에 경제적 기회를 창출할 수 있습니다.PSE의 새로운 전기 자동차 프로그램은 공공, 민간 및 비영리 고객이 차량에 전기를 공급하고, 직장, 주택 및 공공 장소에서 EV 운전자의 충전 요구 사항을 충족하고, 교육 및 홍보 활동을 늘려 EV 채택을 가로막는 장벽을 줄이는 데 도움이 될 것입니다.'),
#  ('교통 전기화 계획의 목적은 무엇입니까?',
#   '교통 전기화 계획의 목적은 순수 탄소 제로 기업 2045를 넘어서겠다는 PSE의 열망의 일환으로 광범위한 교통 전기화를 가속화하기 위한 로드맵을 수립하고 모든 고객의 접근성과 혜택을 높이기 위한 주식 중심 구성 요소를 포함하는 신규 및 확장된 EV 프로그램을 만드는 것입니다.목표에는 PSE가 신뢰할 수 있고 탄력적이며 유연하며 현대화된 전력망을 통해 전기 자동차 충전을 관리하여 미래의 운송 연료로 전기를 안전하게 공급할 수 있도록 하는 것도 포함됩니다.'),
#  ('운송의 전기화가 증가함에 따라 PSE는 부하 관리를 어떻게 처리할 것입니까?',
#   'PSE는 하루 중 최적의 시간에 전기 자동차를 충전하도록 장려하기 위해 다양한 관리형 충전 전략을 테스트할 예정입니다.새로운 EV 프로그램에 참여하는 고객은 EV 충전에 대한 공평한 접근을 촉진하면서 EV 충전으로 인한 최대 영향을 완화하도록 설계된 관리형 충전 프로그램에 자동으로 등록됩니다.관리형 충전 프로그램은 고객에게 무료로 제공되며 언제든지 취소할 수 있습니다.'),
#  ('PSE는 교통 전기화와 관련하여 어떤 프로그램을 도입할 예정입니까?',
#   'PSE는 2023년에 차량, 다세대 충전 및 교육 및 아웃리치를 위한 프로그램을 시작으로 교통 전기화를 중심으로 여러 신규 및 확장된 프로그램을 시작할 예정입니다.교통 전기화 프로그램의 두 번째 단계에는 주거용 단독 주택, 공공 및 중소 규모 직장 충전이 포함됩니다.'),
#  ('교통 전기화 계획과 새로운 전기 자동차 프로그램은 교통 전기화와 그 혜택에 대한 공평한 접근을 어떻게 증진시킬 것입니까?',
#   '교통 전기화 계획에 따라 만들어진 각 프로그램에는 저소득층 고객, 흑인, 원주민 및 유색인종 (BIPOC) 커뮤니티와 해당 지역 사회 기반 조직, 정부 기관 및 부족 단체의 전기화를 지원하기 위한 주식 중심 구성 요소 및 자금 지원이 포함됩니다.'),
#  ('충전 유형에는 어떤 차이가 있나요?',
#   '전기 자동차 충전에는 세 가지 유형이 있습니다.레벨 1은 모든 EV와 함께 제공되는 충전 코드이며 모든 표준 콘센트에 꽂을 수 있습니다.충전 시간당 2~5마일의 주행 거리가 추가됩니다.직장과 다가구 건물, 공공 장소에서 레벨 2 충전 서비스를 이용할 수 있습니다.집에 설치할 수도 있습니다.레벨 2 충전은 시간당 약 25마일의 주행 거리를 추가합니다.DC 고속 충전은 일부 공용 충전소에서 사용할 수 있습니다.이 충전기는 가스 펌프처럼 생겼으며 한 시간 이내에 EV를 완전히 충전할 수 있습니다.충전에 대해 자세히 알아보려면 여기를 클릭하십시오.'),
#  ('집에서 EV를 충전하려면 무엇이 필요한가요?',
#   '집에서 전기 자동차를 충전하려면 차량과 함께 제공되는 레벨 1 충전 코드 외에는 아무것도 필요하지 않습니다.이 코드는 모든 표준 콘센트에 꽂을 수 있습니다.더 빠른 충전을 원한다면 전기 기술자에게 레벨 2 충전기 설치에 대해 문의할 수 있습니다.'),
#  ('레벨 2 충전기를 집에 설치하려면 어떻게 해야 하나요?',
#   '첫 번째 단계는 전기 기술자에게 견적을 받는 것입니다.PSE는 충전기 설치를 전문으로 하는 계약자를 찾는 데 도움을 드릴 수 있습니다. 1-800-562-1482로 에너지 어드바이저에게 전화하거나 권장 에너지 전문가 포털 (PSE 계정으로 로그인한 후 제품 카테고리에서 “그린 에너지”를 선택) 을 방문하시면 됩니다.전기 기술자가 가정의 전기 시스템이 레벨 2 충전기를 처리할 수 있는지 확인하고 필요한 허가를 받은 후에는 충전기를 선택해야 합니다.일부 충전기는 단순히 EV를 충전하는 반면 다른 충전기는 모바일 앱 지원, 예약 충전 및 다른 스마트 홈 제품과의 통합과 같은 옵션을 제공합니다.마지막으로 충전기를 설치할 위치를 결정하십시오.야외에서든 차고에서든 충전기와 EV 사이의 거리를 최대한 짧게 유지하는 것이 좋습니다.'),
#  ('집에 레벨 2 충전기를 설치하는 데 드는 비용은 얼마입니까?',
#   '가정에 레벨 2 충전기를 설치하는 데 드는 비용은 설치 장소 및 전기 기술자와 같은 여러 요인에 따라 달라집니다.표준 설치 비용은 없지만 일반적으로 충전기 및 설치에 대해 총 1,500 달러에서 1,800 달러 사이를 지불해야 합니다.'),
#  ('아파트 또는 콘도에 거주하는 경우 어떻게 EV를 충전할 수 있나요?',
#   '아파트 또는 콘도에 거주하는 건물에 세입자를 위한 충전소가 없고 콘센트가 있는 전용 주차 공간이 없는 경우 전기 자동차를 충전하는 것이 더 복잡할 수 있습니다.충전 옵션에 대해서는 건물 관리자 또는 주택 소유자 협회와 반드시 상의하세요.점점 더 많은 건물들이 거주자들의 편의를 위해 충전소를 제공하기 시작했습니다.고용주가 충전소를 제공하는 경우 직장에서 충전하는 것이 집에서 충전하는 것보다 편리한 대안이 될 수 있습니다.운전을 자주 하지 않는다면 충전이 필요할 때 공용 충전소만 이용해도 괜찮을 수도 있습니다.'),
#  ('집이나 건물에 충전기를 설치하고 있다고 PSE에 알려야 하나요?',
#   '레벨 2 또는 DC 고속 충전기를 설치하는 경우 프로세스 초기에 PSE에 문의하여 건물에 서비스를 제공하는 인프라가 상대적으로 낮은 킬로와트 충전기의 경우에도 필요한 추가 전력을 지원할 수 있는지 확인하는 것이 가장 좋습니다.귀하 또는 귀하의 계약자는 1-888-321-7779 또는 문의 양식을 통해 고객 건설 서비스 팀에 연락할 수 있습니다.설치하려는 충전기의 수와 유형을 알려주시면 저희 팀이 전기 용량을 철저하게 검토할 수 있도록 준비해 두세요.'),
#  ('공용 충전은 어떻게 작동하나요?',
#   '대부분의 충전은 집에서 이루어 지지만, 공용 충전소는 자동차 여행을 하거나 목적지까지 갈 때 약간의 주스만 추가하면 좋습니다.공공 스테이션은 레벨 2 또는 DC 고속 충전을 제공하며 다양한 회사 및 기관에서 운영합니다.대부분의 공공 스테이션을 사용하는 가장 쉬운 방법은 회사 또는 기관의 앱을 사용하는 것입니다. 하지만 일부 스테이션에는 카드 리더가 있거나 전화로 결제할 수 있습니다.주유소와 달리 차를 충전해 두고 심부름이나 간단한 식사를 하거나 주변 산책을 할 수 있습니다.다음 운전자가 충전기를 사용할 수 있도록 EV 충전이 완료될 때까지 돌아와 불필요한 요금을 피하세요.'),
#  ('공용 충전소에서 충전하는 데 드는 비용은 얼마입니까?',
#   '공공 충전소에서의 충전 요금은 물론 분당 요금 또는 사용한 전기 요금 중 어느 것을 사용하느냐에 따라 지역 및 사업자에 따라 달라집니다.일반적으로 공용 충전소는 집에서 충전하는 것보다 더 비쌉니다.PSE Up & Go Electric 공용 스테이션에서는 DC 고속 충전기의 경우 0.42/kWh, 레벨 2 충전기의 경우 0.28달러/kWh를 청구합니다.PSE 충전에 대해 자세히 알아보려면 여기를 클릭하십시오.'),
#  ('모든 공공 충전소에서 EV를 충전할 수 있나요?',
#   '대부분의 경우 공용 충전소에는 모든 전기 자동차 모델에 맞는 연결이 있습니다.가장 큰 예외는 테슬라입니다.Tesla 차량은 Tesla 수퍼차저 네트워크만 사용하지만 Tesla 이외의 스테이션을 사용하려면 구매 가능한 어댑터가 필요합니다.Plugshare.com과 같은 웹 사이트에서는 도착하기 전에 특정 역에서 어떤 연결편을 이용할 수 있는지 확인할 수 있습니다.'),
#  ('공용 충전소는 어떻게 찾을 수 있나요?',
#   '전기 자동차 운전자가 공공 정류소를 찾고 도로 여행을 계획하는 데 도움이 되는 Plugshare.com과 같은 많은 웹사이트와 앱이 있습니다.또한 Google 지도와 Apple Maps에 공용 충전소가 추가되고 있습니다.'),
#  ('차량-전력망 충전은 어떻게 작동하나요?PSE에서 지원하나요?',
#   'V2G (Vehicle-to-Grid) 기술을 사용하면 전기 자동차의 배터리에 저장된 에너지를 그리드로 다시 공급할 수 있습니다.대규모로 사용할 수 있는 V2G 기술은 전력망과 전원 공급을 최적화하는 데 도움이 될 수 있습니다.\nV2G는 고객이 양방향 충전기와 양방향 DC 충전과 호환되는 차량을 사용해야 하는 새로운 기능이며, 이 두 가지 모두 아직 널리 보급되지 않았습니다.현재 V2G와 호환되는 EV는 소수에 불과하며 양방향 충전기는 일반 EV 충전기보다 훨씬 비쌉니다.\nPSE는 현재 V2G 기술을 지원하지 않지만 기능이 발전함에 따라 모니터링을 진행하고 있습니다.V2G를 당사 제품에 통합하기 위한 파일럿 프로그램을 고려할 수 있지만 2024년 이전에는 고려하지 않을 수 있습니다.\nPSE가 V2G를 지원할 때까지 이러한 시스템 중 하나가 그리드로 피드백되면 안전하지 않은 운영으로 간주되어 PSE 서비스가 중단될 수 있습니다.'),
#  ('EV를 가정용 백업 전원으로 사용할 수 있나요?',
#   'V2H 충전 기술은 양방향 전기 자동차 충전기를 사용하여 EV 배터리의 전기를 주택이나 다른 유형의 건물로 공급합니다.\n정상 작동 중에 그리드는 EV 충전기를 포함한 주택이나 다른 유형의 건물에 에너지를 공급합니다.V2H 작동 중에는 그리드의 연결이 끊기고 EV가 가정에 에너지를 공급합니다.\nV2H 작동 중에 EV가 실수로 그리드로 피드백되는 경우 PSE는 이를 안전하지 않은 작동으로 간주하여 PSE 서비스가 중단될 수 있습니다.설치자와 협력하여 V2H 시스템이 안전하게 작동하는지 확인하십시오.\nEV를 사용하여 집에 전원을 공급하려면 양방향 충전기와 양방향 DC 충전과 호환되는 차량이 모두 필요합니다.시장은 이러한 충전기를 더 많이 제공하도록 발전하고 있습니다.'),
#  ('EV는 한 번 충전으로 얼마나 멀리 주행할 수 있나요?',
#   '전기 자동차 기술의 발전으로 주행 거리에 대한 불안감은 과거의 일이 되고 있습니다.신형 EV는 한 번 충전으로 평균 250마일 이상을 주행할 수 있습니다. 이는 불과 몇 년 전에 비해 크게 개선된 수치입니다.즉, 매일 주행에 필요한 것이 무엇이든, 전기차가 이를 충족시킬 가능성이 높습니다.전기차 가이드를 통해 주행 거리별로 새로운 EV 모델을 찾아볼 수 있습니다.'),
#  ('겨울 날씨, 언덕 등은 범위에 어떤 영향을 미칩니까?',
#   '가스 구동 자동차와 마찬가지로 전기 자동차의 효율성은 언덕이나 악천후와 같은 요인에 의해 영향을 받습니다.그러나 주행 조건에 관계없이 EV의 주행 거리를 최대화하기 위한 팁과 요령이 있습니다.예를 들어, 겨울철에는 전원이 켜져 있는 상태에서 EV를 데우거나, 열선 시트와 스티어링 휠을 사용하거나, 회생 브레이크를 이용해 배터리를 충전하는 경우를 들 수 있습니다.'),
#  ('EV 배터리는 안전한가요?',
#   '전기 자동차는 미국에서 판매되는 가스 구동 자동차와 동일한 엄격한 안전 테스트를 거쳐야 하며 동일한 안전 표준을 충족해야 합니다.또한 배터리로 인한 화학 물질 유출을 제한하고, 충돌 시 배터리를 고정하고, 섀시를 고전압 시스템으로부터 격리하기 위한 엄격한 기준을 가지고 있습니다.'),
#  ('배터리를 교체해야 하나요?',
#   '간단한 대답은 배터리를 교체할 필요가 전혀 없다는 것입니다. 하지만 이는 전기 자동차를 운전하고 충전하는 방법과 장소 및 딜러 보증에 따라 달라집니다.현재 대부분의 제조업체는 배터리에 대해 8년/100,000마일 또는 10년/15만 마일 보증을 제공하고 있습니다.연구에 따르면 미국인들은 평균적으로 10년 이하마다 새 차를 구입합니다.더 좋은 점은 EV 배터리 기술이 발전하고 있으며 배터리는 처음에 예상했던 것보다 더 오래 유용성을 유지하고 있다는 것입니다.'),
#  ('전기차는 실제로 환경에 더 좋은가요?',
#   '네.전기 자동차는 운전과 관련된 배기가스 배출량을 엄격하게 살펴보면 가스 구동 자동차보다 환경에 더 좋습니다 (특히 워싱턴 주와 같이 전력 구성이 비교적 깨끗한 지역에서는 더욱 그렇습니다).EV로 바꾸면 운전으로 인한 CO2 배출량을 연간 2톤 이상 줄일 수 있습니다.당사의 전기 자동차 가이드에서는 배기가스 감소에 대해 더 자세히 설명합니다.EV 배터리 생산을 고려하면 그림이 조금 더 복잡해집니다.그러나 전기 및 가스 구동 차량의 제조부터 시작하여 전체 수명 주기를 고려한 최근 연구에 따르면 EV는 전반적으로 여전히 환경에 더 좋은 것으로 나타났습니다.'),
#  ('EV 배터리 생산이 환경에 미치는 영향은 어떻습니까?',
#   '전기 자동차가 가스 구동 자동차보다 전반적으로 환경에 더 좋지만 배터리 생산과 관련된 환경적 영향이 있습니다.책임감 있게 재료를 조달하고 산업 폐기물을 유익하게 재사용하는 것은 현재 배터리 산업이 환경 발자국을 줄이기 위해 사용할 수 있는 최상의 솔루션일 것입니다.배터리 기술이 발전함에 따라 이러한 환경 영향이 줄어들 것으로 기대됩니다.'),
#  ('EV 배터리를 제거하면 어떻게 되나요?',
#   '전기 자동차 배터리의 재사용 및 재활용은 성장하는 산업입니다.신생 기업들은 자동차 제조업체와 협력하여 EV 배터리를 구성하는 재료를 재활용하고 있으며, 최근 통과된 인플레이션 감소법은 배터리에 재활용 재료를 사용하는 자동차 제조업체에 인센티브를 제공합니다.한편, 더 이상 EV에 효율적으로 전원을 공급할 수 없는 배터리는 원래 저장 용량의 약 80% 를 여전히 보유하고 있을 수 있습니다.EV 배터리는 간헐적인 재생 에너지 생성 및 EV 충전소의 저장과 같은 용도로 재사용되고 있습니다.')]

# %%
import pymysql

conn = pymysql.connect(
    host='127.0.0.1',
    user='play',
    password='123',
    database='sk15',
    charset='utf8mb4'
)
cursor = conn.cursor()

# 테이블 생성 (한 번만 실행)
cursor.execute("""
CREATE TABLE IF NOT EXISTS pse_faq (
    id INT AUTO_INCREMENT PRIMARY KEY,
    question TEXT,
    answer TEXT
)
""")

# 데이터 삽입
for question, answer in faq_list:
    cursor.execute("INSERT INTO pse_faq (question, answer) VALUES (%s, %s)", (question, answer))

conn.commit()
conn.close()

# %%
pip install streamlit requests beautifulsoup4 pymysql
# Out:
# Collecting streamlit
#   Downloading streamlit-1.45.1-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: requests in c:\users\playdata\appdata\local\miniconda3\lib\site-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\playdata\appdata\local\miniconda3\lib\site-packages (4.13.4)
# Requirement already satisfied: pymysql in c:\users\playdata\appdata\local\miniconda3\lib\site-packages (1.1.1)
# Collecting altair<6,>=4.0 (from streamlit)
#   Downloading altair-5.5.0-py3-none-any.whl.metadata (11 kB)
# Collecting blinker<2,>=1.5.0 (from streamlit)
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting cachetools<6,>=4.0 (from streamlit)
#   Downloading cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting click<9,>=7.0 (from streamlit)
#   Downloading click-8.2.1-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\playdata\appdata\local\miniconda3\lib\site-packages (from streamlit) (2.2.6)
# Requirement already satisfied: packaging<25,>=20 in c:\users\playdata\appdata\local\miniconda3\lib\site-packages (from streamlit) (24.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\playdata\appdata\local\miniconda3\lib\site-packages (from streamlit) (2.2.3)
# Collecting pillow<12,>=7.1.0 (from streamlit)
#   Downloading pillow-11.2.1-cp310-cp310-win_amd64.whl.metadata (9.1 kB)
# Collecting protobuf<7,>=3.20 (from streamlit)
#   Downloading protobuf-6.31.1-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Collecting pyarrow>=7.0 (from streamlit)
#   Downloading pyarrow-20.0.0-cp310-cp310-win_amd64.whl.metadata (3.4 kB)
# Collecting tenacity<10,>=8.1.0 (from streamlit)
#   Downloading tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting toml<2,>=0.10.1 (from streamlit)
#   Downloading toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\users\playdata\appdata\local\miniconda3\lib\site-packages (from streamlit) (4.13.2)
# Collecting watchdog<7,>=2.1.5 (from streamlit)
#   Downloading watchdog-6.0.0-py3-none-win_amd64.whl.metadata (44 kB)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit)
#   Downloading GitPython-3.1.44-py3-none-any.whl.metadata (13 kB)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\playdata\appdata\local\miniconda3\lib\site-packages (from streamlit) (6.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\playdata\appdata\local\miniconda3\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\playdata\appdata\local\miniconda3\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\playdata\appdata\local\miniconda3\lib\site-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\playdata\appdata\local\miniconda3\lib\site-packages (from requests) (2025.4.26)
# Requirement already satisfied: soupsieve>1.2 in c:\users\playdata\appdata\local\miniconda3\lib\site-packages (from beautifulsoup4) (2.7)
# Requirement already satisfied: jinja2 in c:\users\playdata\appdata\local\miniconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\playdata\appdata\local\miniconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Collecting narwhals>=1.14.2 (from altair<6,>=4.0->streamlit)
#   Downloading narwhals-1.42.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: colorama in c:\users\playdata\appdata\local\miniconda3\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\playdata\appdata\local\miniconda3\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\playdata\appdata\local\miniconda3\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\playdata\appdata\local\miniconda3\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\playdata\appdata\local\miniconda3\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\playdata\appdata\local\miniconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\playdata\appdata\local\miniconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\playdata\appdata\local\miniconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\playdata\appdata\local\miniconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.25.0)
# Requirement already satisfied: six>=1.5 in c:\users\playdata\appdata\local\miniconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Downloading streamlit-1.45.1-py3-none-any.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    -------------- ------------------------- 3.7/9.9 MB 19.8 MB/s eta 0:00:01
#    ------------------------------------ --- 8.9/9.9 MB 22.1 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 20.5 MB/s eta 0:00:00
# Downloading altair-5.5.0-py3-none-any.whl (731 kB)
#    ---------------------------------------- 0.0/731.2 kB ? eta -:--:--
#    --------------------------------------- 731.2/731.2 kB 29.3 MB/s eta 0:00:00
# Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading cachetools-5.5.2-py3-none-any.whl (10 kB)
# Downloading click-8.2.1-py3-none-any.whl (102 kB)
# Downloading GitPython-3.1.44-py3-none-any.whl (207 kB)
# Downloading pillow-11.2.1-cp310-cp310-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ---------------------------------------- 2.7/2.7 MB 30.9 MB/s eta 0:00:00
# Downloading protobuf-6.31.1-cp310-abi3-win_amd64.whl (435 kB)
# Downloading pyarrow-20.0.0-cp310-cp310-win_amd64.whl (25.8 MB)
#    ---------------------------------------- 0.0/25.8 MB ? eta -:--:--
#    ---------- ----------------------------- 6.6/25.8 MB 33.6 MB/s eta 0:00:01
#    -------------------- ------------------- 13.1/25.8 MB 31.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 18.9/25.8 MB 30.6 MB/s eta 0:00:01
#    ---------------------------------------  25.7/25.8 MB 30.7 MB/s eta 0:00:01
#    ---------------------------------------- 25.8/25.8 MB 28.7 MB/s eta 0:00:00
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ---------------------------------------- 0.0/6.9 MB ? eta -:--:--
#    --------------------------- ------------ 4.7/6.9 MB 25.9 MB/s eta 0:00:01
#    ---------------------------------------- 6.9/6.9 MB 25.0 MB/s eta 0:00:00
# Downloading tenacity-9.1.2-py3-none-any.whl (28 kB)
# Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Downloading watchdog-6.0.0-py3-none-win_amd64.whl (79 kB)
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
# Downloading narwhals-1.42.0-py3-none-any.whl (359 kB)
# Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Installing collected packages: watchdog, toml, tenacity, smmap, pyarrow, protobuf, pillow, narwhals, click, cachetools, blinker, pydeck, gitdb, gitpython, altair, streamlit
# Successfully installed altair-5.5.0 blinker-1.9.0 cachetools-5.5.2 click-8.2.1 gitdb-4.0.12 gitpython-3.1.44 narwhals-1.42.0 pillow-11.2.1 protobuf-6.31.1 pyarrow-20.0.0 pydeck-0.9.1 smmap-5.0.2 streamlit-1.45.1 tenacity-9.1.2 toml-0.10.2 watchdog-6.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import streamlit as st
import requests
from bs4 import BeautifulSoup
import pymysql

# 1. URL 설정 및 요청 보내기
url = "https://www.pse.com/ko/pages/electric-cars/electric-vehicles-faq"
headers = {
    "User-Agent": "Mozilla/5.0"
}

# 2. 크롤링 함수
def crawl_faq():
    res = requests.get(url, headers=headers)
    soup = BeautifulSoup(res.text, "html.parser")

    # 질문과 답변 추출
    questions = soup.find_all("p", class_="collapsed")
    answers = soup.find_all("div", class_="panel-body collapse-content")

    # 리스트로 정리
    faq_list = []
    for q, a in zip(questions, answers):
        question = q.text.strip()
        answer = a.text.strip()
        faq_list.append((question, answer))
    
    return faq_list

# 3. MySQL에 데이터 저장 함수
def save_to_mysql(faq_list):
    try:
        conn = pymysql.connect(
            host='127.0.0.1',      # MySQL 서버 주소
            user='play',           # 사용자 이름
            password='123',    # 본인의 MySQL 비밀번호
            database='sk15',       # 데이터베이스 이름
            charset='utf8mb4'      # 한글을 저장할 때 깨지지 않도록 설정
        )
        cursor = conn.cursor()

        # # 테이블 생성 (한 번만 실행)
        # cursor.execute("""
        # CREATE TABLE IF NOT EXISTS pse_faq (
        #     id INT AUTO_INCREMENT PRIMARY KEY,
        #     question TEXT,
        #     answer TEXT
        # )
        # """)

        # 데이터 삽입
        for question, answer in faq_list:
            cursor.execute("INSERT INTO pse_faq (question, answer) VALUES (%s, %s)", (question, answer))

        conn.commit()
        st.success("✅ MySQL에 FAQ 데이터 저장 완료!")
    except pymysql.MySQLError as e:
        st.error(f"❌ MySQL 오류: {e}")
    finally:
        conn.close()

# 4. MySQL에서 FAQ 데이터 불러오는 함수
def load_from_mysql():
    try:
        conn = pymysql.connect(
            host='127.0.0.1',
            user='play',
            password='123',
            database='sk15',
            charset='utf8mb4'
        )
        cursor = conn.cursor()
        cursor.execute("SELECT question, answer FROM pse_faq")

        rows = cursor.fetchall()
        faq_data = [(row[0], row[1]) for row in rows]
        return faq_data

    except pymysql.MySQLError as e:
        st.error(f"❌ MySQL 오류: {e}")
    finally:
        conn.close()

# Streamlit UI
st.title("FAQ 크롤링 및 MySQL 저장")

# 5. 크롤링 버튼 클릭 시 FAQ 크롤링 및 저장
if st.button("FAQ 크롤링 및 MySQL에 저장"):
    with st.spinner("크롤링 중..."):
        faq_list = crawl_faq()
        save_to_mysql(faq_list)

# 6. MySQL에서 저장된 FAQ 데이터 확인
if st.button("저장된 FAQ 데이터 확인"):
    faq_data = load_from_mysql()
    if faq_data:
        for idx, (question, answer) in enumerate(faq_data, 1):
            st.subheader(f"❓ {question}")
            st.write(f"💬 {answer}")
            st.write("-" * 50)
    else:
        st.warning("저장된 FAQ 데이터가 없습니다.")
# Out:
# 2025-06-09 19:49:54.612 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-09 19:49:55.110
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run c:\Users\Playdata\AppData\Local\miniconda3\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-06-09 19:49:55.112 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-09 19:49:55.112 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-09 19:49:55.112 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-09 19:49:55.112 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-09 19:49:55.112 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-09 19:49:55.112 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-09 19:49:55.112 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-09 19:49:55.112 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-09 19:49:55.112 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-09 19:49:55.112 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-09 19:49:55.112 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
